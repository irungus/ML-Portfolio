# %% [markdown]
# # 1.Variables and Data Types
# A variable is a named storage location that holds a value or data
#  - Text Type: str
#  - Numeric Types: int, float, complex
#  - Sequence Types: list, tuple, range
#  - Mapping Type: dict
#  - Set Types: set, frozenset
#  - Boolean Type: bool
#  - Binary Types: bytes, bytearry, memoryview
#  - None Type: NoneType

# %% [markdown]
# # Python Data Types
#
# Python has several built-in data types used to store different kinds of data.
#
# ## i. Text Type
#
# - `str` — String
#   - Represents text or a sequence of characters.
#   - Example: `"Hello World"`
#
# ## ii. Numeric Types
#
# - `int` — Integer
#   - Represents whole numbers, positive or negative.
#   - Example: `25`, `-10`, `0`
#
# - `float` — Floating-point number
#   - Represents numbers containing decimal points.
#   - Example: `25.5`, `3.14`, `-2.5`
#
# - `complex` — Complex number
#   - Represents numbers with a real and imaginary part.
#   - Example: `3 + 4j`
#
# ## iii. Sequence Types
#
# - `list` — List
#   - Represents an ordered and changeable collection of items.
#   - Allows duplicate values.
#   - Example: `[1, 2, 3]`
#
# - `tuple` — Tuple
#   - Represents an ordered and unchangeable collection of items.
#   - Allows duplicate values.
#   - Example: `(1, 2, 3)`
#
# - `range` — Range
#   - Represents a sequence of numbers.
#   - Commonly used with loops.
#   - Example: `range(5)`
#
# ## iv. Mapping Type
#
# - `dict` — Dictionary
#   - Represents data as key-value pairs.
#   - Example: `{"name": "Samuel", "age": 30}`
#
# ## v. Set Types
#
# - `set` — Set
#   - Represents an unordered collection of unique values.
#   - Duplicate values are automatically removed.
#   - Example: `{1, 2, 3}`
#
# - `frozenset` — Frozen Set
#   - Represents an immutable set of unique values.
#   - Example: `frozenset({1, 2, 3})`
#
# ## vi. Boolean Type
#
# - `bool` — Boolean
#   - Represents one of two logical values: `True` or `False`.
#   - Example: `True`
#
# ## vii. Binary Types
#
# - `bytes` — Bytes
#   - Represents an immutable sequence of bytes.
#   - Example: `b"Hello"`
#
# - `bytearray` — Byte Array
#   - Represents a mutable sequence of bytes.
#   - Example: `bytearray(b"Hello")`
#
# - `memoryview` — Memory View
#   - Represents a view of data stored in another binary object.
#   - Allows access to binary data without copying it.
#   - Example: `memoryview(b"Hello")`
#
# ## viii. None Type
#
# - `NoneType` — None
#   - Represents the absence of a value.
#   - The only value of this type is `None`.
#   - Example: `None`
#
# ---
#
# # Summary of Python Data Types
#
# | Category | Type | Represents | Example |
# |---|---|---|---|
# | Text | `str` | Text/String | `"Hello"` |
# | Numeric | `int` | Whole number | `25` |
# | Numeric | `float` | Decimal number | `25.5` |
# | Numeric | `complex` | Complex number | `3 + 4j` |
# | Sequence | `list` | Ordered, changeable collection | `[1, 2, 3]` |
# | Sequence | `tuple` | Ordered, unchangeable collection | `(1, 2, 3)` |
# | Sequence | `range` | Sequence of numbers | `range(5)` |
# | Mapping | `dict` | Key-value pairs | `{"a": 1}` |
# | Set | `set` | Unique unordered values | `{1, 2, 3}` |
# | Set | `frozenset` | Immutable set | `frozenset({1, 2})` |
# | Boolean | `bool` | True/False values | `True` |
# | Binary | `bytes` | Immutable binary data | `b"Hi"` |
# | Binary | `bytearray` | Mutable binary data | `bytearray(b"Hi")` |
# | Binary | `memoryview` | View of binary data | `memoryview(b"Hi")` |
# | None | `NoneType` | Absence of a value | `None` |
#
# ---
#
# # Checking Data Types
#
# You can use the `type()` function to determine the data type of a value.

# %%
name = "Samuel Irungu"
val = 20
val2 = 20.5
val3 = 3j
lst = ["apple", "banana", "cherry"]
tpl = ("apple", "banana", "cherry")
rng = range(6)
dct = {"name": "Samuel", "age": 36}
st = {"apple", "banana", "cherry"}
fst = frozenset({"apple", "banana", "cherry"})
bl = True
byt = b"Hello"
bytarr = bytearray(5)
mmview = memoryview(bytes(5))
Nn = None

# %%
# String
print(name)
# integer, float, complex
print(val,val2,val3, sep="\n")
# list, tuple , range
print(lst, tpl, rng, sep="\n")
# Dictionary
print(dct)
# Set, frozenset
print(st,fst, sep="\n")
#Boolean
print(bl)
# Bytes, bytearray, memoryview
print(byt, bytarr, mmview, sep="\n")
#None
print(Nn)
# Out:
# Samuel Irungu
# 20
# 20.5
# 3j
# ['apple', 'banana', 'cherry']
# ('apple', 'banana', 'cherry')
# range(0, 6)
# {'name': 'Samuel', 'age': 36}
# {'apple', 'cherry', 'banana'}
# frozenset({'apple', 'cherry', 'banana'})
# True
# b'Hello'
# bytearray(b'\x00\x00\x00\x00\x00')
# ...
# None

# %%
# String
print(f"name is of:{type(name)}")
# integer, float, complex
print(f"val is of: {type (val)}", f"val2 is of: {type(val2)}", f"val3 is of: {type(val3)}", sep="\n")
# List, Tuple, Range
print(f"lst is of: {type(lst)}", f"tpl is of: {type(tpl)}", f"rng is of: {type(rng)}", sep="\n")

# Dictionary
print(f"dct is of: {type(dct)}")

# Set, Frozenset
print(f"st is of: {type(st)}", f"fst is of: {type(fst)}", sep="\n")

# Boolean
print(f"bl is of: {type(bl)}")

# Bytes, Bytearray, Memoryview
print(f"byt is of: {type(byt)}", f"bytarr is of: {type(bytarr)}", f"mmview is of: {type(mmview)}", sep="\n")

# None
print(f"Nn is of: {type(Nn)}")
# Out:
# name is of:<class 'str'>
# val is of: <class 'int'>
# val2 is of: <class 'float'>
# val3 is of: <class 'complex'>
# lst is of: <class 'list'>
# tpl is of: <class 'tuple'>
# rng is of: <class 'range'>
# dct is of: <class 'dict'>
# st is of: <class 'set'>
# fst is of: <class 'frozenset'>
# bl is of: <class 'bool'>
# byt is of: <class 'bytes'>
# bytarr is of: <class 'bytearray'>
# mmview is of: <class 'memoryview'>
# Nn is of: <class 'NoneType'>

# %% [markdown]
# # 2.Conditional Statements
# Conditional statements allow python to make decisions based on whether a condition is `True` or `False`
#
#   `"if this is true, do this: otherwise, do something else."`

# %% [markdown]
#  Basic `if` statement

# %%
age = 25

if age>=18:
    print ('Adult')
# Out:
# Adult

# %% [markdown]
# `if` ......`else` statement

# %%
age =15

if age >= 18:
    print ("Adult")
else:
    print ("Minor")
# Out:
# Minor

# %% [markdown]
# `if`....`elif`....`else`

# %%
score = 30

if score >= 80:
    grade = "A"
elif score >= 70:
    grade = "B"
elif score >= 60:
    grade = "C"
elif score >= 50:
    grade = "D"
else:
    grade = "F"

print(grade)
# Out:
# F

# %% [markdown]
# Machine Learning Example

# %%
r2 = 0.87

if r2 >= 0.80:
    print("Strong Model Performance")
elif r2 >= 0.60:
    print("Moderate Model Performance")
else:
    print("Low model performance")
# Out:
# Strong Model Performance

# %% [markdown]
# Conditional statements inside loops

# %%
dbh = [5,12,25,3,30,35]

for dbh in dbh:
    if dbh <= 10:
        print(dbh, "Too Small")
    elif dbh <=20:
        print(dbh, "Medium")
    else:
        print (dbh, "Large")
# Out:
# 5 Too Small
# 12 Medium
# 25 Large
# 3 Too Small
# 30 Large
# 35 Large

# %% [markdown]
# # 3.Loops

# %% [markdown]
# There are two main python loops `for loop` and `while loop`
#   - `for` repeats over a collection of items
#   - `while` repeat while a condition remains `True`

# %%
fruits = ["Apple","Cherry", "Banana", "Grapes"]

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Cherry
# Banana
# Grapes

# %%
for i in range(4,10):
    print(i)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(0,10, 3):
    print(i)
# Out:
# 0
# 3
# 6
# 9

# %%
counter = 1
 
while counter <= 5:
    print(counter)
    counter+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Important `for` use when you know you are iterating over `while` use when you want to continue until a condition is met or changes

# %% [markdown]
# Lets use nested loops especially when we have lets multiple datasets,multiple algorithms or multiple paramater combinations

# %%
species = ["Acacia","Musa"]
models = ["Random Forest", "XGBoost", "Gradient Boosting"]

for tree in species:
    for model in models:
        print(tree, " - ", model)
# Out:
# Acacia  -  Random Forest
# Acacia  -  XGBoost
# Acacia  -  Gradient Boosting
# Musa  -  Random Forest
# Musa  -  XGBoost
# Musa  -  Gradient Boosting

# %% [markdown]
# # 4.Functions

# %% [markdown]
# # 5.List Comprehensions

# %% [markdown]
# # 6.Modules

# %% [markdown]
# # 7.Exception Handling

# %% [markdown]
# # 8.Numpy Introduction

# %% [markdown]
# # 9.Pandas Introduction

# %% [markdown]
# # 10.Loading CSV Data

# %% [markdown]
# # 11. Inspecting a Dataset

# %% [markdown]
# # 12. Missing Values
